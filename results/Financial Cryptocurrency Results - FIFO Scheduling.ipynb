# %% [markdown]
# ## Introduction
#
# ### Definitions
#
# ##### Global Blocktree
# A global tree maintained during the simulation used to determine certain statistics
#
# ##### Node Tree
# A Node has a tree structure consisting of tree blocks just like in the Longest Chain Protocol.
#
# ##### Main Chain
# On a tree structure, the main chain is defined in this protocol as the Longest Chain from the Genesis block to a leaf block.
#
# ##### Node Pool
# A node also has a pool structure consisting of pool blocks.
#
# ##### Tree Block
# A block on the global blocktree or in a node's local tree.
#
# ##### Pool Block
# A block in a node's local pool. The block may or may not be referenced by the next tree block proposed by the node.
#
# ##### Finalized
# A block is considered finalized in two cases:
#
# 1) If in a tree block - if the block is `k` blocks deep on the main chain
# 2) If in a pool block - if the pool block is referenced by a tree block that is finalized
#
# A transaction is considered finalized if it is in a finalized block

# %% [markdown]
# ## Simulation Description
#
# We measure multiple metrics to understand a transactions behavior during the simulation.
#
# #### Throughput
# How many of the transactions generated actually get finalized in the simulation?
#
# #### Unique Throughput
# How many of the unique transactions generated actually get finalized in the simulation?
#
# #### Pool Block Arrival Latency
# How long does it take for a transaction to make it into a pool block?
#
# #### Pool Block Reference Latency
# How long does it take for a transaction to make it into a pool block and get referenced?
#
# #### Main Chain Arrival Latency
# How long does it take for a transaction to make it onto the main chain (for both pool blocks and tree blocks)?
#
# #### Finalization Latency
# How long does it take for a transaction to be finalized once it arrives on the main chain?

# %% [markdown]
# ### Experimental Parameters

# %%
import numpy as np
# %matplotlib inline

num_tests = 2
n_trials = 2
tree_proposal_rates = np.linspace(0.1, 0.1, num_tests)
pool_proposal_rates = np.linspace(0.1, 0.2, num_tests)

# Use these to overwrite and run real tests
num_tests = 10
n_trials = 5
tree_proposal_rates = np.linspace(0.1, 0.1, num_tests)
pool_proposal_rates = np.linspace(0.1, 3, num_tests)

import json

# Create experimental parameters and write to JSON file

params = {'Block tree proposal rate parameter': 0,
 'Block pool proposal rate parameter': 0,
 'Transaction rate parameter': 0,
 'Block size (txs)': 50,
 'Duration (sec)': 0,
 'Fork choice rule': 'longest-chain-with-pool',
 'Transaction scheduling rule': 'FIFO',
 'Network model': 'Decker-Wattenhorf',
 'Number of adversaries': 1,
 'Number of nodes': 10,
 'Probability of error in transaction confirmation': 0.1,
 'Transaction dataset': 'poisson',
 'Logging enabled': True}

# %% [markdown]
# ### Run experiments

# %%
import os, shutil, pprint, glob, csv

pp = pprint.PrettyPrinter()
os.system('touch longest_chain_with_pool.json')
os.chdir('..')

import metrics

throughputs = {}
unique_throughputs = {}
pool_block_arrival_latencies = {}
pool_block_ref_latencies = {}
main_chain_arrival_latencies = {}
finalization_latencies = {}
emptiness = {}

for i in range(0, num_tests):
    tree_rate = tree_proposal_rates[i]
    pool_rate = pool_proposal_rates[i]
    params['Block tree proposal rate parameter'] = tree_rate
    params['Block pool proposal rate parameter'] = pool_rate
    params['Transaction rate parameter'] = 0.9*pool_rate*int(params['Block size (txs)'])
    params['Duration (sec)'] = 100/pool_rate
    d = {}
    d['setting-name'] = f'longest-chain-with-pool'
    d[f'longest-chain-with-pool'] = params
    print('Parameters:')
    pp.pprint(d)
    with open('results/longest_chain_with_pool.json', 'w+') as outfile:
        json.dump(d, outfile)
    throughputs[(tree_rate, pool_rate)] = []
    unique_throughputs[(tree_rate, pool_rate)] = []
    pool_block_arrival_latencies[(tree_rate, pool_rate)] = []
    pool_block_ref_latencies[(tree_rate, pool_rate)] = []
    main_chain_arrival_latencies[(tree_rate, pool_rate)] = []
    finalization_latencies[(tree_rate, pool_rate)] = []
    emptiness[(tree_rate, pool_rate)] = []
    for trial in range(0, n_trials):
        os.system('python3 main.py -f results/longest_chain_with_pool.json')
        throughput, unique_throughput = metrics.compute_throughputs()
        
        throughputs[(tree_rate, pool_rate)].append(throughput)
        unique_throughputs[(tree_rate, pool_rate)].append(unique_throughput)
        
        avg_pool_block_arr_latency, avg_pool_block_ref_latency, avg_main_chain_arrival_latency, avg_finalization_latency = metrics.compute_latency()
        
        pool_block_arrival_latencies[(tree_rate, pool_rate)].append(avg_pool_block_arr_latency)
        pool_block_ref_latencies[(tree_rate, pool_rate)].append(avg_pool_block_ref_latency)
        main_chain_arrival_latencies[(tree_rate, pool_rate)].append(avg_main_chain_arrival_latency)
        finalization_latencies[(tree_rate, pool_rate)].append(avg_finalization_latency)
        
        _emptiness = metrics.compute_emptiness()
        emptiness[(tree_rate, pool_rate)].append(_emptiness)
    
os.chdir('results/')
os.remove('longest_chain_with_pool.json')
print('Throughputs:\n', throughputs)
print('Unique Throughputs:\n', unique_throughputs)
print('Pool Block Arrival Latencies:\n', pool_block_arrival_latencies)
print('Pool Block Reference Latencies:\n', pool_block_ref_latencies)
print('Main Chain Arrival Latencies:\n', main_chain_arrival_latencies)
print('Finalization Latencies:\n', finalization_latencies)
print('Emptiness:\n', emptiness)
# Out:
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 0.1,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 1000.0,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 4.500000000000001,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 0.42222222222222217,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 236.84210526315792,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 18.999999999999996,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 0.7444444444444444,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 134.32835820895525,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 33.5,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 1.0666666666666667,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 93.75,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 48.0,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 1.3888888888888888,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 72.0,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 62.5,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 1.711111111111111,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 58.44155844155844,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 77.0,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 2.033333333333333,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 49.18032786885246,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 91.49999999999999,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 2.3555555555555556,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 42.45283018867924,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 106.0,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 2.6777777777777776,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 37.344398340248965,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 120.49999999999999,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 3.0,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 33.333333333333336,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 135.0,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Throughputs:
#  {(0.1, 0.1): [15.335, 10.658333333333333, 14.895, 10.12, 10.493333333333334], (0.1, 0.42222222222222217): [8.033333333333333, 10.376666666666667, 12.065, 9.098333333333333, 14.368333333333334], (0.1, 0.7444444444444444): [11.195, 13.675, 8.075, 10.208333333333334, 12.618333333333334], (0.1, 1.0666666666666667): [9.361666666666666, 9.908333333333333, 3.441666666666667, 6.001666666666667, 7.128333333333333], (0.1, 1.3888888888888888): [4.408333333333333, 4.223333333333334, 10.525, 4.828333333333333, 5.358333333333333], (0.1, 1.711111111111111): [5.635, 10.396666666666667, 4.798333333333333, 8.418333333333333, 4.255], (0.1, 2.033333333333333): [5.006666666666667, 3.625, 10.895, 10.666666666666666, 4.7683333333333335], (0.1, 2.3555555555555556): [8.268333333333333, 5.9366666666666665, 4.405, 5.428333333333334, 3.5883333333333334], (0.1, 2.6777777777777776): [5.903333333333333, 5.81, 8.835, 8.931666666666667, 2.3783333333333334], (0.1, 3.0): [8.678333333333333, 4.843333333333334, 6.361666666666666, 5.368333333333333, 3.6933333333333334]}
# Unique Throughputs:
#  {(0.1, 0.1): [7.12, 6.251666666666667, 6.953333333333333, 6.4383333333333335, 6.638333333333334], (0.1, 0.42222222222222217): [2.89, 2.4066666666666667, 2.8316666666666666, 2.86, 2.1466666666666665], (0.1, 0.7444444444444444): [2.421666666666667, 1.9666666666666666, 2.3983333333333334, 2.6533333333333333, 3.02], (0.1, 1.0666666666666667): [1.72, 1.3383333333333334, 1.755, 1.3666666666666667, 1.83], (0.1, 1.3888888888888888): [1.7633333333333334, 1.33, 1.6283333333333334, 1.5766666666666667, 2.0966666666666667], (0.1, 1.711111111111111): [1.4466666666666668, 1.2583333333333333, 1.5466666666666666, 1.9316666666666666, 1.5483333333333333], (0.1, 2.033333333333333): [1.0383333333333333, 1.1333333333333333, 1.31, 1.6183333333333334, 1.485], (0.1, 2.3555555555555556): [1.9483333333333333, 1.4933333333333334, 0.925, 1.7766666666666666, 1.3416666666666666], (0.1, 2.6777777777777776): [1.0016666666666667, 1.6266666666666667, 1.8166666666666667, 1.52, 1.0783333333333334], (0.1, 3.0): [1.1866666666666668, 1.4916666666666667, 2.0883333333333334, 1.2683333333333333, 1.5366666666666666]}
# Pool Block Arrival Latencies:
#  {(0.1, 0.1): [32.893355027473184, 52.21996742122248, 31.510720527135817, 43.88937678078658, 31.82483097657314], (0.1, 0.42222222222222217): [70.53551497806934, 83.22141603896077, 86.14106062547138, 64.3007103307674, 82.45937927947845], (0.1, 0.7444444444444444): [48.369944241253606, 68.72815528346851, 57.61550920660552, 50.106923986978245, 35.09215585648943], (0.1, 1.0666666666666667): [50.95309276105982, 45.14948259225169, 42.32372559611597, 50.85860756719464, 45.7300101014105], (0.1, 1.3888888888888888): [30.703137169492567, 37.084260837477025, 34.85121325055091, 40.88343484799827, 27.728669954232704], (0.1, 1.711111111111111): [29.731346295012724, 40.060955880493914, 28.645403469792186, 30.040290025903495, 30.436536269598115], (0.1, 2.033333333333333): [32.92610359939231, 26.031927551965897, 24.76084605811017, 22.536173537364895, 24.79353080390307], (0.1, 2.3555555555555556): [22.171830174760352, 22.116920890332, 28.135126910033392, 22.485047653675547, 24.046431704867533], (0.1, 2.6777777777777776): [18.255144370570466, 22.77066006091401, 24.185941296685016, 20.653713306316867, 16.791378247313624], (0.1, 3.0): [17.086943154079822, 24.710086306084385, 15.073100348673107, 24.00428106736723, 20.626256611939148]}
# Pool Block Reference Latencies:
#  {(0.1, 0.1): [9.352036304221334, 10.072003469182004, 10.661667876516324, 10.073474564613552, 6.449182393030389], (0.1, 0.42222222222222217): [6.495572321387522, 7.784468460399285, 10.640898295181648, 10.762623041793205, 19.140557718594483], (0.1, 0.7444444444444444): [10.83771620340034, 8.356899841573313, 8.554034601433768, 9.54819009831383, 9.864810035382853], (0.1, 1.0666666666666667): [8.381260796889086, 6.406243321348743, 3.791743743100932, 13.846920137234104, 5.926212781532233], (0.1, 1.3888888888888888): [1.0693739652072594, 9.915339373599442, 8.8737053189643, 7.332415776257553, 8.787879793412534], (0.1, 1.711111111111111): [8.161959819495895, 17.88067032204048, 6.998909609264038, 10.470488533227842, 8.55412809779386], (0.1, 2.033333333333333): [0.7433503840668498, 3.3075324125951786, 13.694159918405996, 9.540349553341887, 9.187137614485748], (0.1, 2.3555555555555556): [16.10145333673364, 21.40760067611119, 9.80444447415871, 6.366685981471163, 9.676288776722656], (0.1, 2.6777777777777776): [19.10162230893123, 13.260391144251123, 17.72336925275428, 12.126285416159304, 3.7728249005639847], (0.1, 3.0): [13.366845210695613, 26.020539276349645, 22.764409096230434, 13.920193943847044, 9.68055209491401]}
# Main Chain Arrival Latencies:
#  {(0.1, 0.1): [8.489084209375289, 11.625840383866095, 9.612525028716504, 12.26780586773007, 5.650924790858947], (0.1, 0.42222222222222217): [5.144882636888846, 7.321436465269427, 11.643900920008882, 10.148773262241242, 12.010943301454208], (0.1, 0.7444444444444444): [8.61679325126758, 8.86413359840703, 4.654553318333776, 6.998073005653311, 5.490854746218271], (0.1, 1.0666666666666667): [3.53728510893537, 3.9830956971326223, -0.3446124030815479, -2.3851053201705374, 2.9660912036513363], (0.1, 1.3888888888888888): [-1.5642074658068892, 0.48375394559841, 7.125573022147882, 2.0046382761931913, 1.009619622784442], (0.1, 1.711111111111111): [0.9250840707494475, 4.895150861232714, 0.7104864380533839, 1.5735760884750014, -0.15520645718150938], (0.1, 2.033333333333333): [-7.626318997086991, 1.6696886733684513, 9.704117284384957, 6.0204704729570775, 0.6284884117210283], (0.1, 2.3555555555555556): [3.1396273478820467, 0.9173867668703212, -8.222013070143024, 2.4339318365812908, -0.7986695103573455], (0.1, 2.6777777777777776): [-0.5484466720995275, 1.2079687002563362, 2.171253437483996, 7.631933508203102, 1.8222074402930983], (0.1, 3.0): [6.4163258788952335, 0.13356624007286474, 1.939661880833055, 1.8297376276327246, 1.4993509068996256]}
# Finalization Latencies:
#  {(0.1, 0.1): [37.089807549841396, 48.51109866544908, 36.334789807650004, 45.37089568853297, 41.14110299487039], (0.1, 0.42222222222222217): [21.6706326321645, 20.193237773942187, 15.609822961531785, 21.994187119883094, 15.827549231483397], (0.1, 0.7444444444444444): [8.26276225610105, 9.20537322135139, 13.403091317164131, 10.552226209881459, 7.6446825899288955], (0.1, 1.0666666666666667): [10.579555025454827, 11.973619431779893, 17.37921169322103, 14.924737957080369, 12.996855062882348], (0.1, 1.3888888888888888): [9.988312737856214, 11.459490772475627, 6.557163625004265, 8.345565254649465, 6.063451153576381], (0.1, 1.711111111111111): [6.523706399740378, 5.667688842604224, 8.163592404945346, 7.516052312080717, 6.4319040711838], (0.1, 2.033333333333333): [8.720051126732095, 11.726538387408901, -0.7927535628068717, 5.078639754798646, 4.174369994987183], (0.1, 2.3555555555555556): [3.800162862793214, 4.464149256485276, 7.374469741972158, 4.399377388716421, 5.350960493646422], (0.1, 2.6777777777777776): [4.0627554885268315, 4.017293852147992, 3.231345169662909, 2.0137392024107186, 8.724234499985837], (0.1, 3.0): [3.6038838185747775, 3.596499909248362, 3.555165708045761, 2.370276355621452, 2.9318590829717426]}
# Emptiness:
#  {(0.1, 0.1): [3.2780487804878047, -36.60843373493976, 1.6825396825396826, -17.862433862433864, 2.851674641148325], (0.1, 0.42222222222222217): [-281.9, -345.9911504424779, -329.9811320754717, -270.18811881188117, -165.97530864197532], (0.1, 0.7444444444444444): [-155.95402298850576, -243.06766917293234, -224.09375, -215.58653846153845, -136.14414414414415], (0.1, 1.0666666666666667): [-342.66101694915255, -207.7516339869281, -371.93457943925233, -220.31313131313132, -247.3], (0.1, 1.3888888888888888): [-224.71621621621622, -438.9125, -198.30927835051546, -348.28915662650604, -225.03157894736842], (0.1, 1.711111111111111): [-224.16161616161617, -132.90740740740742, -175.71428571428572, -116.65573770491804, -71.48837209302326], (0.1, 2.033333333333333): [-251.16, -119.3731343283582, -211.54545454545453, -107.75471698113208, -161.00892857142858], (0.1, 2.3555555555555556): [-138.175, -185.17857142857142, -201.83928571428572, -149.3859649122807, -163.36486486486487], (0.1, 2.6777777777777776): [-151.5581395348837, -125.84126984126983, -214.97826086956522, -96.4625, -241.25], (0.1, 3.0): [-175.5151515151515, -117.41111111111111, -83.97674418604652, -82.41379310344827, -71.56382978723404]}

# %% [markdown]
# ### Compute Averages
#
# Average throughput is the number of finalized transactions divided by the duration of the experiment.
#
# Average main chain latency is the time for a transaction to be added to the global blocktree - the timestamp the transaction was generated.
#
# Average pool block latency is the time for a transaction to be added to a pool block AND referenced by a tree block.
#
# Average finalization latency is the time for a transaction to be k blocks deep - to be added to the global blocktree.

# %%
def compute_avg_std_dev(d):
    avgs = {}
    std_devs = {}
    print(d)
    for rate in d:
        avgs[rate] = sum(d[rate])/len(d[rate])
        std_devs[rate] = np.std(d[rate])
        
    return avgs, std_devs

avg_throughputs, throughput_sd = compute_avg_std_dev(throughputs)
avg_uniq_throughputs, uniq_throughput_sd = compute_avg_std_dev(unique_throughputs)
avg_pool_block_arr_lat , pool_block_arr_sd = compute_avg_std_dev(pool_block_arrival_latencies)
avg_pool_block_ref_lat, pool_block_ref_sd = compute_avg_std_dev(pool_block_ref_latencies)
avg_mca_lat, mca_lat_sd  = compute_avg_std_dev(main_chain_arrival_latencies)
avg_fin_lat, fin_lat_sd  = compute_avg_std_dev(finalization_latencies)
avg_emp, emp_sd = compute_avg_std_dev(emptiness)
# Out:
# {(0.1, 0.1): [15.335, 10.658333333333333, 14.895, 10.12, 10.493333333333334], (0.1, 0.42222222222222217): [8.033333333333333, 10.376666666666667, 12.065, 9.098333333333333, 14.368333333333334], (0.1, 0.7444444444444444): [11.195, 13.675, 8.075, 10.208333333333334, 12.618333333333334], (0.1, 1.0666666666666667): [9.361666666666666, 9.908333333333333, 3.441666666666667, 6.001666666666667, 7.128333333333333], (0.1, 1.3888888888888888): [4.408333333333333, 4.223333333333334, 10.525, 4.828333333333333, 5.358333333333333], (0.1, 1.711111111111111): [5.635, 10.396666666666667, 4.798333333333333, 8.418333333333333, 4.255], (0.1, 2.033333333333333): [5.006666666666667, 3.625, 10.895, 10.666666666666666, 4.7683333333333335], (0.1, 2.3555555555555556): [8.268333333333333, 5.9366666666666665, 4.405, 5.428333333333334, 3.5883333333333334], (0.1, 2.6777777777777776): [5.903333333333333, 5.81, 8.835, 8.931666666666667, 2.3783333333333334], (0.1, 3.0): [8.678333333333333, 4.843333333333334, 6.361666666666666, 5.368333333333333, 3.6933333333333334]}
# {(0.1, 0.1): [7.12, 6.251666666666667, 6.953333333333333, 6.4383333333333335, 6.638333333333334], (0.1, 0.42222222222222217): [2.89, 2.4066666666666667, 2.8316666666666666, 2.86, 2.1466666666666665], (0.1, 0.7444444444444444): [2.421666666666667, 1.9666666666666666, 2.3983333333333334, 2.6533333333333333, 3.02], (0.1, 1.0666666666666667): [1.72, 1.3383333333333334, 1.755, 1.3666666666666667, 1.83], (0.1, 1.3888888888888888): [1.7633333333333334, 1.33, 1.6283333333333334, 1.5766666666666667, 2.0966666666666667], (0.1, 1.711111111111111): [1.4466666666666668, 1.2583333333333333, 1.5466666666666666, 1.9316666666666666, 1.5483333333333333], (0.1, 2.033333333333333): [1.0383333333333333, 1.1333333333333333, 1.31, 1.6183333333333334, 1.485], (0.1, 2.3555555555555556): [1.9483333333333333, 1.4933333333333334, 0.925, 1.7766666666666666, 1.3416666666666666], (0.1, 2.6777777777777776): [1.0016666666666667, 1.6266666666666667, 1.8166666666666667, 1.52, 1.0783333333333334], (0.1, 3.0): [1.1866666666666668, 1.4916666666666667, 2.0883333333333334, 1.2683333333333333, 1.5366666666666666]}
# {(0.1, 0.1): [32.893355027473184, 52.21996742122248, 31.510720527135817, 43.88937678078658, 31.82483097657314], (0.1, 0.42222222222222217): [70.53551497806934, 83.22141603896077, 86.14106062547138, 64.3007103307674, 82.45937927947845], (0.1, 0.7444444444444444): [48.369944241253606, 68.72815528346851, 57.61550920660552, 50.106923986978245, 35.09215585648943], (0.1, 1.0666666666666667): [50.95309276105982, 45.14948259225169, 42.32372559611597, 50.85860756719464, 45.7300101014105], (0.1, 1.3888888888888888): [30.703137169492567, 37.084260837477025, 34.85121325055091, 40.88343484799827, 27.728669954232704], (0.1, 1.711111111111111): [29.731346295012724, 40.060955880493914, 28.645403469792186, 30.040290025903495, 30.436536269598115], (0.1, 2.033333333333333): [32.92610359939231, 26.031927551965897, 24.76084605811017, 22.536173537364895, 24.79353080390307], (0.1, 2.3555555555555556): [22.171830174760352, 22.116920890332, 28.135126910033392, 22.485047653675547, 24.046431704867533], (0.1, 2.6777777777777776): [18.255144370570466, 22.77066006091401, 24.185941296685016, 20.653713306316867, 16.791378247313624], (0.1, 3.0): [17.086943154079822, 24.710086306084385, 15.073100348673107, 24.00428106736723, 20.626256611939148]}
# {(0.1, 0.1): [9.352036304221334, 10.072003469182004, 10.661667876516324, 10.073474564613552, 6.449182393030389], (0.1, 0.42222222222222217): [6.495572321387522, 7.784468460399285, 10.640898295181648, 10.762623041793205, 19.140557718594483], (0.1, 0.7444444444444444): [10.83771620340034, 8.356899841573313, 8.554034601433768, 9.54819009831383, 9.864810035382853], (0.1, 1.0666666666666667): [8.381260796889086, 6.406243321348743, 3.791743743100932, 13.846920137234104, 5.926212781532233], (0.1, 1.3888888888888888): [1.0693739652072594, 9.915339373599442, 8.8737053189643, 7.332415776257553, 8.787879793412534], (0.1, 1.711111111111111): [8.161959819495895, 17.88067032204048, 6.998909609264038, 10.470488533227842, 8.55412809779386], (0.1, 2.033333333333333): [0.7433503840668498, 3.3075324125951786, 13.694159918405996, 9.540349553341887, 9.187137614485748], (0.1, 2.3555555555555556): [16.10145333673364, 21.40760067611119, 9.80444447415871, 6.366685981471163, 9.676288776722656], (0.1, 2.6777777777777776): [19.10162230893123, 13.260391144251123, 17.72336925275428, 12.126285416159304, 3.7728249005639847], (0.1, 3.0): [13.366845210695613, 26.020539276349645, 22.764409096230434, 13.920193943847044, 9.68055209491401]}
# {(0.1, 0.1): [8.489084209375289, 11.625840383866095, 9.612525028716504, 12.26780586773007, 5.650924790858947], (0.1, 0.42222222222222217): [5.144882636888846, 7.321436465269427, 11.643900920008882, 10.148773262241242, 12.010943301454208], (0.1, 0.7444444444444444): [8.61679325126758, 8.86413359840703, 4.654553318333776, 6.998073005653311, 5.490854746218271], (0.1, 1.0666666666666667): [3.53728510893537, 3.9830956971326223, -0.3446124030815479, -2.3851053201705374, 2.9660912036513363], (0.1, 1.3888888888888888): [-1.5642074658068892, 0.48375394559841, 7.125573022147882, 2.0046382761931913, 1.009619622784442], (0.1, 1.711111111111111): [0.9250840707494475, 4.895150861232714, 0.7104864380533839, 1.5735760884750014, -0.15520645718150938], (0.1, 2.033333333333333): [-7.626318997086991, 1.6696886733684513, 9.704117284384957, 6.0204704729570775, 0.6284884117210283], (0.1, 2.3555555555555556): [3.1396273478820467, 0.9173867668703212, -8.222013070143024, 2.4339318365812908, -0.7986695103573455], (0.1, 2.6777777777777776): [-0.5484466720995275, 1.2079687002563362, 2.171253437483996, 7.631933508203102, 1.8222074402930983], (0.1, 3.0): [6.4163258788952335, 0.13356624007286474, 1.939661880833055, 1.8297376276327246, 1.4993509068996256]}
# {(0.1, 0.1): [37.089807549841396, 48.51109866544908, 36.334789807650004, 45.37089568853297, 41.14110299487039], (0.1, 0.42222222222222217): [21.6706326321645, 20.193237773942187, 15.609822961531785, 21.994187119883094, 15.827549231483397], (0.1, 0.7444444444444444): [8.26276225610105, 9.20537322135139, 13.403091317164131, 10.552226209881459, 7.6446825899288955], (0.1, 1.0666666666666667): [10.579555025454827, 11.973619431779893, 17.37921169322103, 14.924737957080369, 12.996855062882348], (0.1, 1.3888888888888888): [9.988312737856214, 11.459490772475627, 6.557163625004265, 8.345565254649465, 6.063451153576381], (0.1, 1.711111111111111): [6.523706399740378, 5.667688842604224, 8.163592404945346, 7.516052312080717, 6.4319040711838], (0.1, 2.033333333333333): [8.720051126732095, 11.726538387408901, -0.7927535628068717, 5.078639754798646, 4.174369994987183], (0.1, 2.3555555555555556): [3.800162862793214, 4.464149256485276, 7.374469741972158, 4.399377388716421, 5.350960493646422], (0.1, 2.6777777777777776): [4.0627554885268315, 4.017293852147992, 3.231345169662909, 2.0137392024107186, 8.724234499985837], (0.1, 3.0): [3.6038838185747775, 3.596499909248362, 3.555165708045761, 2.370276355621452, 2.9318590829717426]}
# {(0.1, 0.1): [3.2780487804878047, -36.60843373493976, 1.6825396825396826, -17.862433862433864, 2.851674641148325], (0.1, 0.42222222222222217): [-281.9, -345.9911504424779, -329.9811320754717, -270.18811881188117, -165.97530864197532], (0.1, 0.7444444444444444): [-155.95402298850576, -243.06766917293234, -224.09375, -215.58653846153845, -136.14414414414415], (0.1, 1.0666666666666667): [-342.66101694915255, -207.7516339869281, -371.93457943925233, -220.31313131313132, -247.3], (0.1, 1.3888888888888888): [-224.71621621621622, -438.9125, -198.30927835051546, -348.28915662650604, -225.03157894736842], (0.1, 1.711111111111111): [-224.16161616161617, -132.90740740740742, -175.71428571428572, -116.65573770491804, -71.48837209302326], (0.1, 2.033333333333333): [-251.16, -119.3731343283582, -211.54545454545453, -107.75471698113208, -161.00892857142858], (0.1, 2.3555555555555556): [-138.175, -185.17857142857142, -201.83928571428572, -149.3859649122807, -163.36486486486487], (0.1, 2.6777777777777776): [-151.5581395348837, -125.84126984126983, -214.97826086956522, -96.4625, -241.25], (0.1, 3.0): [-175.5151515151515, -117.41111111111111, -83.97674418604652, -82.41379310344827, -71.56382978723404]}

# %% [markdown]
# ### Extract Finalization Depth and Delta for Blocks

# %%
import csv
if os.path.isfile('../logs/stats.csv'):
    with open('../logs/stats.csv', newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        for row in reader:
            if row[0]=='Finalization depth':
                k = int(row[1])
            elif row[0]=='Average network latency for blocks (sec)':
                delta = float(row[1])

# %% [markdown]
# ### Plotting the results

# %%
import matplotlib.pylab as plt

def plot_results(title, xlabel, ylabel, x, y, std_dev):
    y_arr = np.array(list(y.values()))
    sd = np.array(list(std_dev.values()))
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.grid(True)
    
    plt.plot(x, y_arr, label='observed rate')
    plt.errorbar(x, y_arr, sd, capsize=5, linestyle='None', marker='*')
    plt.show()

    
    
x = np.array([key[1] for key in avg_throughputs.keys()])
plot_results(
f'Transaction Throughput vs. Pool Block Proposal Rate (k={k}, delta={delta})',
'Pool Block Proposal Rate (blocks/sec)',
'Throughput (txs/sec)',
x,
avg_throughputs,
throughput_sd,
)

# %%
plot_results(
f'Unique Transaction Throughput vs. Pool Block Proposal Rate (k={k}, delta={delta})',
'Pool Block Proposal Rate (blocks/sec)',
'Unique Throughput (txs/sec)',
x,
avg_uniq_throughputs,
uniq_throughput_sd,
)

# %%
plot_results(
f'Pool Block Arrival Latency vs. Pool Block Proposal Rate (k={k}, delta={delta})',
'Pool Block Proposal Rate (blocks/sec)',
'Pool Block Arrival Latency (sec)',
x,
avg_pool_block_arr_lat,
pool_block_arr_sd,
)

# %%
plot_results(
f'Pool Block Reference Latency vs. Pool Block Proposal Rate (k={k}, delta={delta})',
'Pool Block Proposal Rate (blocks/sec)',
'Pool Block Reference Latency (sec)',
x,
avg_pool_block_ref_lat,
pool_block_ref_sd,
)

# %%
plot_results(
f'Main Chain Arrival Latency vs. Pool Block Proposal Rate (k={k}, delta={delta})',
'Pool Block Proposal Rate (blocks/sec)',
'Main Chain Arrival Latency (sec)',
x,
avg_mca_lat,
mca_lat_sd,
)

# %%
plot_results(
f'Finalization Latency vs. Pool Block Proposal Rate (k={k}, delta={delta})',
'Pool Block Proposal Rate (blocks/sec)',
'Finalization Latency (sec)',
x,
avg_fin_lat,
fin_lat_sd,
)

# %%
plot_results(
f'Emptiness vs. Pool Block Proposal Rate (k={k}, delta={delta})',
'Pool Block Proposal Rate (blocks/sec)',
'Emptiness (txs)',
x,
avg_emp,
emp_sd,
)

# %% [markdown]
# ### Results
#
# We can look through the logs of the blocks to understand the process a block undergoes:

# %%
with open('../logs/blocks.csv') as f:
    for line in f.readlines()[:10]:
        print(line)
# Out:
# id,parent id,proposal timestamp,pool block timestamp,finalization timestamp,depth,finalized,emptiness,transactions
#
# Genesis,None,0,None,4.051901052362753,0,True,0,
#
# 5c4ee,Genesis,11.809232579892175,None,17.010279021244738,1,True,3,f22c7f996b;b07c8e1959;e97e9d4349;362999e319;8b8cffb679;15bc79df87;c2f8777033;a07367191e;09a6359149;1119072b53;ce2d79c735;a5c8590ee1;5c433456f4;eb09d4679a;54c56212b4;bbbe427bfd;ab18932ab2;06a107dea9;8bdbe47e81;da97458ce5;c20b78fb6a;f02ebe7f9b;e201bcce3e;b24488b771;aa93284221;c0faa6295e;d210862835;9082eda4b8;6bc5b970c4;61425c3638;7c1566413d;2d4993c3c9;5bb08682e1;fc6cbf3a66;24e6ffef01;c87d613edc;46b8e30af7;fa4ad59933;cf7dcdcb8e;0d4de94597;edacc6bb86;f6f8260a2c;f2d97e8e0f;2c60bab685;c62696ce9e;7d33623789;454c91f7e0;6ea0951b36;4f1cd31858;15bc98fa80;5bc2e8628c
#
# 14ad5,None,4.603725196331648,,17.010279021244738,NA,True,74,f22c7f996b;b07c8e1959;e97e9d4349;362999e319;8b8cffb679;15bc79df87;c2f8777033;a07367191e;09a6359149;1119072b53;ce2d79c735;a5c8590ee1;5c433456f4;eb09d4679a;54c56212b4;bbbe427bfd;ab18932ab2;06a107dea9;8bdbe47e81;da97458ce5;c20b78fb6a;f02ebe7f9b;e201bcce3e;b24488b771
#
# d65ef,None,1.202770953411211,,17.010279021244738,NA,True,0,
#
# 3a232,None,2.7346705574411727,,17.010279021244738,NA,True,0,d3ceef174f
#
# c2d30,None,4.599745190008811,,17.010279021244738,NA,True,0,
#
# 8cc21,None,6.902391641925428,,17.010279021244738,NA,True,0,b140d4b87a
#
# 7f9fb,None,4.051901052362753,,17.010279021244738,NA,True,0,
#
# 84777,None,5.251755542828285,,17.010279021244738,NA,True,0,e8aa9f8ece;e284cb9ebc;28f41d432b;ade54a79b1;d30f9ca849

# %% [markdown]
# Additionally, we can visualize the results to see the global blocktree. In the following image, blue nodes indicate tree blocks on the main chain and yellow blocks indicate tree blocks
# off the main chain (i.e. 'orphan blocks').
# ![title](../logs/blocktree.png)

# %% [markdown]
# We can look through the logs to understand the process a transaction undergoes. A transaction can
#
# 1) Be a pool or a tree transaction
# 2) Be on the main chain or not on the main chain
# 3) Be finalized or not finalized
#
# Hence, we will analyze each of the following cases:
# 1) A pool transaction on the main chain that is finalized
# 2) A pool transaction not on the main chain
# 3) A tree transaction on the main chain that is finalized
# 4) A tree transaction on the main chain that is not finalized
# 5) A tree transaction not on the main chain

# %%
import csv

finalized_main_chain_pool_tx = None
not_on_main_chain_pool_tx = None
finalized_main_chain_tree_tx = None
unfinalized_main_chain_tree_tx = None
not_on_main_chain_tree_tx = None

with open('../logs/transactions.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    row_count = 0
    for row in reader:
        if row['finalization timestamps']!='None'and row['main chain arrival timestamp']!='None' and row['pool block reference timestamp']!='None' and finalized_main_chain_pool_tx==None:
            finalized_main_chain_pool_tx = row
        elif row['main chain arrival timestamp']=='None' and row['pool block reference timestamp']!='None' and not_on_main_chain_pool_tx==None:
            not_on_main_chain_pool_tx = row
        elif row['finalization timestamps']!='None' and row['main chain arrival timestamp']!='None' and row['pool block reference timestamp']=='None' and finalized_main_chain_tree_tx==None:
            finalized_main_chain_tree_tx = row
        elif row['finalization timestamps']=='None' and row['main chain arrival timestamp']!='None' and row['pool block reference timestamp']=='None' and unfinalized_main_chain_tree_tx==None:
            unfinalized_main_chain_tree_tx = row
        elif row['main chain arrival timestamp']=='None' and row['pool block reference timestamp']=='None' and not_on_main_chain_tree_tx==None: 
            not_on_main_chain_tree_tx = row
        if row_count<10:
            print(row)
        row_count+=1
# Out:
# OrderedDict([('id', 'e8aa9f8ece'), ('source node', '7'), ('generated timestamp', '0.7617269359417066'), ('pool block arrival timestamp', '18.2225520045987'), ('pool block reference timestamp', '22.728600884134373'), ('main chain arrival timestamp', '21.707861322590382'), ('finalization timestamps', '5.792588451604485;17.5962231650453;15.206408170386107;17.010279021244738;17.010279021244738;17.010279021244738;19.34731956918161;21.707861322590382;23.8300634697535;24.177785366874016;24.177785366874016;24.177785366874016')])
# OrderedDict([('id', '84c5766c53'), ('source node', '0'), ('generated timestamp', '1.9086841427694787'), ('pool block arrival timestamp', '17.18055402608765'), ('pool block reference timestamp', '22.728600884134373'), ('main chain arrival timestamp', '21.707861322590382'), ('finalization timestamps', '5.845484189432435;6.851782807984604;17.5962231650453;20.890421831103737;16.49647233917213;17.010279021244738;17.010279021244738;17.010279021244738;17.010279021244738;17.010279021244738;19.34731956918161;21.707861322590382;23.8300634697535;24.177785366874016;24.177785366874016;24.177785366874016')])
# OrderedDict([('id', '989ab69114'), ('source node', '9'), ('generated timestamp', '1.5156957881671789'), ('pool block arrival timestamp', '17.18055402608765'), ('pool block reference timestamp', '22.728600884134373'), ('main chain arrival timestamp', '21.707861322590382'), ('finalization timestamps', '11.647601436546534;17.5962231650453;17.010279021244738;17.010279021244738;19.34731956918161;21.707861322590382;23.8300634697535;24.177785366874016;24.177785366874016;24.177785366874016')])
# OrderedDict([('id', '0bc253d3be'), ('source node', '9'), ('generated timestamp', '3.0226253607882603'), ('pool block arrival timestamp', '17.18055402608765'), ('pool block reference timestamp', '22.728600884134373'), ('main chain arrival timestamp', '21.707861322590382'), ('finalization timestamps', '17.5962231650453;17.010279021244738;19.34731956918161;21.707861322590382;23.8300634697535;24.177785366874016;24.177785366874016;24.177785366874016')])
# OrderedDict([('id', 'b140d4b87a'), ('source node', '1'), ('generated timestamp', '0.9820710252166558'), ('pool block arrival timestamp', '18.2225520045987'), ('pool block reference timestamp', '22.728600884134373'), ('main chain arrival timestamp', '21.707861322590382'), ('finalization timestamps', '4.20912870602611;17.5962231650453;15.206408170386107;17.010279021244738;17.010279021244738;17.010279021244738;19.34731956918161;21.707861322590382;23.8300634697535;24.177785366874016;24.177785366874016;24.177785366874016')])
# OrderedDict([('id', 'd3ceef174f'), ('source node', '2'), ('generated timestamp', '0.13468916394423364'), ('pool block arrival timestamp', '17.18055402608765'), ('pool block reference timestamp', '22.728600884134373'), ('main chain arrival timestamp', '21.707861322590382'), ('finalization timestamps', '3.6267413605558323;17.5962231650453;17.010279021244738;17.010279021244738;21.707861322590382;22.966055813843425;23.8300634697535;24.177785366874016;24.177785366874016;24.177785366874016')])
# OrderedDict([('id', '96ae2bfddb'), ('source node', '0'), ('generated timestamp', '1.1577028615864584'), ('pool block arrival timestamp', '17.18055402608765'), ('pool block reference timestamp', '22.728600884134373'), ('main chain arrival timestamp', '21.707861322590382'), ('finalization timestamps', '5.845484189432435;6.851782807984604;17.5962231650453;20.890421831103737;16.49647233917213;17.010279021244738;17.010279021244738;17.010279021244738;17.010279021244738;17.010279021244738;21.707861322590382;23.8300634697535;24.177785366874016;24.177785366874016')])
# OrderedDict([('id', 'c57f182da0'), ('source node', '2'), ('generated timestamp', '1.5912551317671735'), ('pool block arrival timestamp', '14.941383996247176'), ('pool block reference timestamp', '22.728600884134373'), ('main chain arrival timestamp', '21.707861322590382'), ('finalization timestamps', '17.5962231650453;17.010279021244738;22.966055813843425;23.8300634697535;24.177785366874016;24.177785366874016')])
# OrderedDict([('id', 'bf59b052ed'), ('source node', '6'), ('generated timestamp', '0.9104044331440595'), ('pool block arrival timestamp', '14.941383996247176'), ('pool block reference timestamp', '22.728600884134373'), ('main chain arrival timestamp', '21.707861322590382'), ('finalization timestamps', '8.668562645049647;17.5962231650453;17.010279021244738;17.010279021244738;19.34731956918161;23.8300634697535;24.177785366874016;24.177785366874016')])
# OrderedDict([('id', 'bcd65483e1'), ('source node', '4'), ('generated timestamp', '0.33115276648039643'), ('pool block arrival timestamp', '15.938164727119284'), ('pool block reference timestamp', '22.728600884134373'), ('main chain arrival timestamp', '21.707861322590382'), ('finalization timestamps', '11.809232579892175;16.0987940952558;17.5962231650453;17.010279021244738;17.010279021244738;17.010279021244738;23.8300634697535;24.69510294374733;24.177785366874016;24.177785366874016')])

# %%
print(f'Finalized Pool Transaction:\n{finalized_main_chain_pool_tx}')
print(f'Pool Transaction Not on Main Chain:\n{not_on_main_chain_pool_tx}')
print(f'Finalized Tree Transaction:\n{finalized_main_chain_tree_tx}')
print(f'Unfinalized Tree Transaction:\n{unfinalized_main_chain_tree_tx}')
print(f'Tree Transaction Not on Main Chain:\n{not_on_main_chain_tree_tx}')
# Out:
# Finalized Pool Transaction:
# OrderedDict([('id', 'e8aa9f8ece'), ('source node', '7'), ('generated timestamp', '0.7617269359417066'), ('pool block arrival timestamp', '18.2225520045987'), ('pool block reference timestamp', '22.728600884134373'), ('main chain arrival timestamp', '21.707861322590382'), ('finalization timestamps', '5.792588451604485;17.5962231650453;15.206408170386107;17.010279021244738;17.010279021244738;17.010279021244738;19.34731956918161;21.707861322590382;23.8300634697535;24.177785366874016;24.177785366874016;24.177785366874016')])
# Pool Transaction Not on Main Chain:
# OrderedDict([('id', 'e6b05c36ae'), ('source node', '7'), ('generated timestamp', '2.009444194608278'), ('pool block arrival timestamp', '6.859456520458901'), ('pool block reference timestamp', '13.521039627276313'), ('main chain arrival timestamp', 'None'), ('finalization timestamps', 'None')])
# Finalized Tree Transaction:
# None
# Unfinalized Tree Transaction:
# None
# Tree Transaction Not on Main Chain:
# OrderedDict([('id', '4ced188d45'), ('source node', '7'), ('generated timestamp', '7.017153176331251'), ('pool block arrival timestamp', '25.217576906331686'), ('pool block reference timestamp', 'None'), ('main chain arrival timestamp', 'None'), ('finalization timestamps', 'None')])

# %% [markdown]
# Let's consider the first case of the finalized pool transaction. If we look into `blocks.csv`,
# we should be able to see that the transaction's main chain arrival timestamp and pool block timestamp
# should be equivalent to a tree block's proposal time. Additionally, the finalization time should be
# the tree block's finalization time.

# %%
with open('../logs/blocks.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    if finalized_main_chain_pool_tx!=None:
        for row in reader:
            if finalized_main_chain_pool_tx['id'] in row['transactions']:
                print(row)
                break
# Out:
# OrderedDict([('id', '84777'), ('parent id', 'None'), ('proposal timestamp', '5.251755542828285'), ('pool block timestamp', ''), ('finalization timestamp', '17.010279021244738'), ('depth', 'NA'), ('finalized', 'True'), ('emptiness', '0'), ('transactions', 'e8aa9f8ece;e284cb9ebc;28f41d432b;ade54a79b1;d30f9ca849')])

# %% [markdown]
# Now let's consider the second case of the pool transaction not on the main chain.
# We should see that it belongs to a block that is not finalized and not on the main chain, indicated
# by the fact the block's finalization timestamp and main chain arrival timestamp will both be `'None'`. However, the pool block timestamp should be equal to the block's proposal timestamp.

# %%
with open('../logs/blocks.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    if not_on_main_chain_pool_tx!=None:
        for row in reader:
            if not_on_main_chain_pool_tx['id'] in row['transactions']:
                print(row)
                break
# Out:
# OrderedDict([('id', 'de555'), ('parent id', 'None'), ('proposal timestamp', '8.935157471173488'), ('pool block timestamp', ''), ('finalization timestamp', 'None'), ('depth', 'NA'), ('finalized', 'False'), ('emptiness', '0'), ('transactions', 'e8aa9f8ece;e284cb9ebc;28f41d432b;ade54a79b1;d30f9ca849;e6b05c36ae;d01ad1d677;74a5a19c95;68ae27f17b;2bd93889db;fc7d16f089;b0312b1dab;142d11145b;51dfbabbec;7abcb4d94f;6e1a767c1a;d45c2a40e5;c2ee0d3df5;18bc116004;a8d1c5aef6;978d5222f2;bfd7234fe4;46de2c994c;83b44f2f16;2b79c95e64;d2306455ef;a5d2860b52;d8c8d87474;44d3c039d6;cff3eba04e;4bad0dc74d;a69dd66c7f;098471c1be;586de22383;02bb2201d6;25ba11a0ad;331c94541f;00b3ceaef7;6ad63be7bb')])

# %% [markdown]
# The third case is the tree finalized tree transaction on the main chain. We should see that it
# belongs to a block with equal finalization and main chain arrival timestamps, but a pool block timestamp equal to `'None'`.

# %%
with open('../logs/blocks.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    if finalized_main_chain_tree_tx!=None:
        for row in reader:
            if finalized_main_chain_tree_tx['id'] in row['transactions']:
                print(row)
                break

# %% [markdown]
# The fourth case is the unfinalized tree transaction on the main chain. We should see that it
# belongs to a block with equal main chain arrival timestamp, but pool block and finalization
# timestamps equal to `'None'`.

# %%
with open('../logs/blocks.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    if unfinalized_main_chain_tree_tx!=None:
        for row in reader:
            if unfinalized_main_chain_tree_tx['id'] in row['transactions']:
                print(row)
                break

# %% [markdown]
# The final case is the tree transaction not on the main chain. The block is not used for any statistics and is not logged.
