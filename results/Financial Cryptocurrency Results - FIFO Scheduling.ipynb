# %% [markdown]
# ## Introduction
#
# ### Definitions
#
# ##### Global Blocktree
# A global tree maintained during the simulation used to determine certain statistics
#
# ##### Node Tree
# A Node has a tree structure consisting of tree blocks just like in the Longest Chain Protocol.
#
# ##### Main Chain
# On a tree structure, the main chain is defined in this protocol as the Longest Chain from the Genesis block to a leaf block.
#
# ##### Node Pool
# A node also has a pool structure consisting of pool blocks.
#
# ##### Tree Block
# A block on the global blocktree or in a node's local tree.
#
# ##### Pool Block
# A block in a node's local pool. The block may or may not be referenced by the next tree block proposed by the node.
#
# ##### Finalized
# A block is considered finalized in two cases:
#
# 1) If in a tree block - if the block is `k` blocks deep on the main chain
# 2) If in a pool block - if the pool block is referenced by a tree block that is finalized
#
# A transaction is considered finalized if it is in a finalized block

# %% [markdown]
# ## Simulation Description
#
# We measure multiple metrics to understand a transactions behavior during the simulation.
#
# #### Throughput
# How many of the transactions generated actually get finalized in the simulation?
#
# #### Unique Throughput
# How many of the unique transactions generated actually get finalized in the simulation?
#
# #### Pool Block Arrival Latency
# How long does it take for a transaction to make it into a pool block?
#
# #### Pool Block Reference Latency
# How long does it take for a transaction to make it into a pool block and get referenced?
#
# #### Main Chain Arrival Latency
# How long does it take for a transaction to make it onto the main chain (for both pool blocks and tree blocks)?
#
# #### Finalization Latency
# How long does it take for a transaction to be finalized once it arrives on the main chain?

# %% [markdown]
# ### Experimental Parameters

# %%
import numpy as np, json
# %matplotlib inline

num_tests = 2
n_trials = 2
tree_proposal_rates = np.linspace(0.1, 0.1, num_tests)
pool_proposal_rates = np.linspace(0.1, 0.2, num_tests)

# Use these to overwrite and run real tests
num_tests = 10
n_trials = 5
tree_proposal_rates = np.linspace(0.1, 0.1, num_tests)
pool_proposal_rates = np.linspace(0.3, 5, num_tests)

# Create experimental parameters and write to JSON file

params = {'Block tree proposal rate parameter': 0,
 'Block pool proposal rate parameter': 0,
 'Transaction rate parameter': 0,
 'Block size (txs)': 50,
 'Duration (sec)': 0,
 'Fork choice rule': 'longest-chain-with-pool',
 'Transaction scheduling rule': 'FIFO',
 'Network model': 'Decker-Wattenhorf',
 'Number of adversaries': 1,
 'Number of nodes': 10,
 'Probability of error in transaction confirmation': 0.1,
 'Transaction dataset': 'poisson',
 'Logging enabled': True}

# %% [markdown]
# ### Run experiments

# %%
import os, shutil, pprint, glob, csv

pp = pprint.PrettyPrinter()
os.system('touch longest_chain_with_pool.json')
os.chdir('..')

import metrics

throughputs = {}
unique_throughputs = {}
pool_block_arrival_latencies = {}
pool_block_ref_latencies = {}
main_chain_arrival_latencies = {}
finalization_latencies = {}
emptiness = {}

for i in range(0, num_tests):
    tree_rate = tree_proposal_rates[i]
    pool_rate = pool_proposal_rates[i]
    params['Block tree proposal rate parameter'] = tree_rate
    params['Block pool proposal rate parameter'] = pool_rate
    params['Transaction rate parameter'] = 0.9*pool_rate*int(params['Block size (txs)'])
    params['Duration (sec)'] = 500/pool_rate
    d = {}
    d['setting-name'] = f'longest-chain-with-pool'
    d[f'longest-chain-with-pool'] = params
    print('Parameters:')
    pp.pprint(d)
    with open('results/longest_chain_with_pool.json', 'w+') as outfile:
        json.dump(d, outfile)
    throughputs[(tree_rate, pool_rate)] = []
    unique_throughputs[(tree_rate, pool_rate)] = []
    pool_block_arrival_latencies[(tree_rate, pool_rate)] = []
    pool_block_ref_latencies[(tree_rate, pool_rate)] = []
    main_chain_arrival_latencies[(tree_rate, pool_rate)] = []
    finalization_latencies[(tree_rate, pool_rate)] = []
    emptiness[(tree_rate, pool_rate)] = []
    for trial in range(0, n_trials):
        os.system('python3 main.py -f results/longest_chain_with_pool.json')
        throughput, unique_throughput = metrics.compute_throughputs()
        
        throughputs[(tree_rate, pool_rate)].append(throughput)
        unique_throughputs[(tree_rate, pool_rate)].append(unique_throughput)
        
        avg_pool_block_arr_latency, avg_pool_block_ref_latency, avg_main_chain_arrival_latency, avg_finalization_latency = metrics.compute_latency()
        
        pool_block_arrival_latencies[(tree_rate, pool_rate)].append(avg_pool_block_arr_latency)
        pool_block_ref_latencies[(tree_rate, pool_rate)].append(avg_pool_block_ref_latency)
        main_chain_arrival_latencies[(tree_rate, pool_rate)].append(avg_main_chain_arrival_latency)
        finalization_latencies[(tree_rate, pool_rate)].append(avg_finalization_latency)
        
        _emptiness = metrics.compute_emptiness()
        emptiness[(tree_rate, pool_rate)].append(_emptiness)
    
os.chdir('results/')
os.remove('longest_chain_with_pool.json')
print('Throughputs:\n', throughputs)
print('Unique Throughputs:\n', unique_throughputs)
print('Pool Block Arrival Latencies:\n', pool_block_arrival_latencies)
print('Pool Block Reference Latencies:\n', pool_block_ref_latencies)
print('Main Chain Arrival Latencies:\n', main_chain_arrival_latencies)
print('Finalization Latencies:\n', finalization_latencies)
print('Emptiness:\n', emptiness)
# Out:
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 0.3,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 1666.6666666666667,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 13.5,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 0.8222222222222222,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 608.1081081081081,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 37.0,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 1.3444444444444446,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 371.900826446281,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 60.50000000000001,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 1.866666666666667,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 267.85714285714283,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 84.00000000000001,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 2.388888888888889,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 209.30232558139537,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 107.5,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 2.911111111111111,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 171.7557251908397,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 131.0,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 3.4333333333333336,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 145.63106796116503,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 154.50000000000003,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 3.9555555555555557,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 126.40449438202246,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 178.0,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 4.477777777777778,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 111.66253101736973,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 201.5,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Parameters:
# {'longest-chain-with-pool': {'Block pool proposal rate parameter': 5.0,
#                              'Block size (txs)': 50,
#                              'Block tree proposal rate parameter': 0.1,
#                              'Duration (sec)': 100.0,
#                              'Fork choice rule': 'longest-chain-with-pool',
#                              'Logging enabled': True,
#                              'Network model': 'Decker-Wattenhorf',
#                              'Number of adversaries': 1,
#                              'Number of nodes': 10,
#                              'Probability of error in transaction confirmation': 0.1,
#                              'Transaction dataset': 'poisson',
#                              'Transaction rate parameter': 225.0,
#                              'Transaction scheduling rule': 'FIFO'},
#  'setting-name': 'longest-chain-with-pool'}
# Throughputs:
#  {(0.1, 0.3): [67.715, 63.52166666666667, 60.96666666666667, 64.69666666666667, 60.67666666666667], (0.1, 0.8222222222222222): [54.16166666666667, 52.16833333333334, 53.641666666666666, 54.858333333333334, 57.596666666666664], (0.1, 1.3444444444444446): [49.84, 54.05833333333333, 56.04333333333334, 60.861666666666665, 52.141666666666666], (0.1, 1.866666666666667): [40.89833333333333, 48.55166666666667, 54.37, 56.526666666666664, 49.04666666666667], (0.1, 2.388888888888889): [47.946666666666665, 46.38333333333333, 48.321666666666665, 55.125, 43.721666666666664], (0.1, 2.911111111111111): [42.765, 37.03333333333333, 54.983333333333334, 51.25833333333333, 43.48833333333334], (0.1, 3.4333333333333336): [39.30833333333333, 44.22666666666667, 50.748333333333335, 41.00666666666667, 53.24666666666667], (0.1, 3.9555555555555557): [38.68833333333333, 33.406666666666666, 52.25833333333333, 37.843333333333334, 39.69166666666667], (0.1, 4.477777777777778): [38.61, 35.781666666666666, 59.25666666666667, 21.345, 46.205], (0.1, 5.0): [19.72833333333333, 45.218333333333334, 36.833333333333336, 28.301666666666666, 45.44]}
# Unique Throughputs:
#  {(0.1, 0.3): [18.045, 18.39666666666667, 18.645, 19.208333333333332, 19.198333333333334], (0.1, 0.8222222222222222): [10.118333333333334, 9.928333333333333, 12.13, 10.068333333333333, 10.026666666666667], (0.1, 1.3444444444444446): [11.01, 9.783333333333333, 9.088333333333333, 7.225, 7.593333333333334], (0.1, 1.866666666666667): [6.7316666666666665, 6.965, 6.968333333333334, 6.243333333333333, 8.165], (0.1, 2.388888888888889): [6.4783333333333335, 6.9383333333333335, 5.871666666666667, 8.11, 6.58], (0.1, 2.911111111111111): [6.398333333333333, 6.581666666666667, 5.93, 4.758333333333334, 6.42], (0.1, 3.4333333333333336): [4.89, 4.42, 4.373333333333333, 3.9116666666666666, 5.06], (0.1, 3.9555555555555557): [4.706666666666667, 5.613333333333333, 4.18, 5.368333333333333, 5.145], (0.1, 4.477777777777778): [3.9916666666666667, 4.001666666666667, 3.4183333333333334, 3.6216666666666666, 3.285], (0.1, 5.0): [4.1466666666666665, 3.7733333333333334, 5.883333333333334, 4.948333333333333, 3.966666666666667]}
# Pool Block Arrival Latencies:
#  {(0.1, 0.3): [422.2872514946153, 421.34357364603125, 397.6600240587891, 367.11370411058954, 391.7086042265639], (0.1, 0.8222222222222222): [247.99956861476102, 228.51753175055265, 208.23332281986606, 224.37163963283405, 213.5257069726107], (0.1, 1.3444444444444446): [134.1399292407048, 137.8532243660617, 145.29459002188884, 176.4854411295612, 147.76428073543275], (0.1, 1.866666666666667): [123.17119854005712, 116.1854832258646, 134.12895667605648, 102.63945325466729, 112.00491413268298], (0.1, 2.388888888888889): [87.24566684353324, 89.4972553032986, 101.37524237271211, 93.96768229332606, 88.65803239096581], (0.1, 2.911111111111111): [81.44477756013092, 83.32139310696908, 67.21280039448996, 87.52241766625022, 79.84221750028912], (0.1, 3.4333333333333336): [83.03932003821753, 61.05872361990775, 80.15965710692178, 96.21535505299191, 78.77920537970805], (0.1, 3.9555555555555557): [71.68854678274423, 59.2373857508904, 65.6935470917367, 54.06737281303187, 50.006912419781024], (0.1, 4.477777777777778): [76.26833573157599, 57.85283654633201, 74.13636637507787, 65.5416695283717, 69.71610656534948], (0.1, 5.0): [52.997357705226065, 56.50262289756535, 55.39253308295434, 50.54865301652074, 69.99465349563859]}
# Pool Block Reference Latencies:
#  {(0.1, 0.3): [8.45327777994252, 8.282652739350125, 7.823349835719727, 7.2869694184756355, 7.2454430873217515], (0.1, 0.8222222222222222): [7.911252431258511, 9.337061034378475, 6.170303041450118, 10.192655256222722, 9.603333935504953], (0.1, 1.3444444444444446): [7.370688189685184, 8.178711915051709, 9.334844000544418, 9.503604761734465, 11.476148186916475], (0.1, 1.866666666666667): [3.341113218937008, 5.960290474624409, 10.005003068830847, 11.874806617780889, 9.431383309220061], (0.1, 2.388888888888889): [8.831669358432874, 6.67299471110893, 11.421245360572966, 11.74207588142177, 19.608943172222965], (0.1, 2.911111111111111): [13.176776311690737, 7.397258781349635, 13.992771623632791, 2.5613892036476544, 6.602528383951047], (0.1, 3.4333333333333336): [6.47659587299396, 13.435838323561926, 13.057300988984645, 10.632722132629993, 11.718314586161009], (0.1, 3.9555555555555557): [7.968529560468304, 14.802968722952121, 7.644372564921025, 6.7990511572786545, 13.13728707316362], (0.1, 4.477777777777778): [12.488176547891898, 17.496949861998594, 15.472047020580824, 6.916108335643269, 19.975098436249638], (0.1, 5.0): [8.548581470915165, 13.228970729247981, 5.790729356903623, 6.197105533686459, 11.678101196052484]}
# Main Chain Arrival Latencies:
#  {(0.1, 0.3): [9.757315934003747, 8.066560607099579, 8.756598438034993, 7.625432966417224, 8.917218518676046], (0.1, 0.8222222222222222): [7.08054316513556, 9.014126965061257, 4.297995179912096, 9.787727146094628, 8.55963498755671], (0.1, 1.3444444444444446): [6.455307718533878, 6.347092929282611, 8.101067231762546, 7.324969472916603, 10.113473697879598], (0.1, 1.866666666666667): [2.1021879714972163, 4.997456342661084, 7.041188565269241, 5.225173816150206, 8.234530699378446], (0.1, 2.388888888888889): [7.0521414778036124, 3.7267838285492387, 7.285084533795381, 9.828594604475683, 8.623478741665885], (0.1, 2.911111111111111): [8.395588699592345, 7.148328294664633, 11.511319169278169, 0.05419293557058525, 0.8933597210324922], (0.1, 3.4333333333333336): [2.1464070849196974, 9.387953134223315, 7.549960800267771, -1.9612416970568625, 6.023500573794064], (0.1, 3.9555555555555557): [5.691714878227302, 2.0327243681527944, 4.851208407677463, 4.509229026362884, 2.2924149943291328], (0.1, 4.477777777777778): [2.179970338785805, 4.703923670496927, 12.812396573849242, 0.11509920348434818, 13.169767657860776], (0.1, 5.0): [3.845786769472618, 6.212369553133225, 2.8643666278436157, 4.148013443861553, 3.266234593787015]}
# Finalization Latencies:
#  {(0.1, 0.3): [22.944397465037135, 23.65024163595842, 23.73552009487866, 23.487210397612483, 22.81233211443678], (0.1, 0.8222222222222222): [13.244089121317407, 13.172170666414711, 12.446988695262847, 11.929629728108772, 12.195900441284257], (0.1, 1.3444444444444446): [7.964844394368605, 8.224372222411068, 6.731023738431287, 8.334592336968216, 11.421859693054008], (0.1, 1.866666666666667): [10.400794887689475, 8.207987780424133, 5.837221327627939, 7.165437426501934, 7.005405851381213], (0.1, 2.388888888888889): [5.5832683712045394, 6.577716072742226, 7.808588114859585, 4.226241657531864, 5.911473824815438], (0.1, 2.911111111111111): [4.0816721075265034, 8.153436713023048, 4.2631968398736415, 5.3618193471928555, 5.445619919026354], (0.1, 3.4333333333333336): [11.689336530743228, 7.209205533390121, 5.271809818271432, 7.517259810680867, 6.381029680738744], (0.1, 3.9555555555555557): [3.3428196044818126, 5.43707400078342, 3.354103534078854, 4.9935488577871805, 7.187909103178953], (0.1, 4.477777777777778): [5.298566369594682, 4.332051063654062, 2.0128441255898517, 4.978926564510737, 6.5551252660340475], (0.1, 5.0): [5.676652510555093, 5.383919163099735, 2.7994964841729857, 4.329288056479688, 7.471924120868809]}
# Emptiness:
#  {(0.1, 0.3): [-1574.3715670436188, -1600.9620437956205, -1705.9054263565893, -1459.5197740112994, -1651.0], (0.1, 0.8222222222222222): [-1541.5391156462586, -1384.0536912751677, -1567.1042830540036, -1429.1589285714285, -1384.6954887218046], (0.1, 1.3444444444444446): [-1325.8173515981734, -1279.9543378995434, -1188.9679358717435, -1382.5521885521885, -1238.0947368421052], (0.1, 1.866666666666667): [-1530.9655172413793, -1192.2080536912752, -1169.6374622356495, -1289.3148148148148, -1406.3976744186045], (0.1, 2.388888888888889): [-1533.6030042918455, -1195.2485768500949, -1253.9036777583187, -955.1065989847716, -1218.5168738898756], (0.1, 2.911111111111111): [-1321.6036217303822, -1268.4864864864865, -1045.6566371681415, -1186.5933852140079, -1216.7393526405451], (0.1, 3.4333333333333336): [-1542.0868486352358, -770.0558659217877, -1092.2429718875503, -924.6964047936085, -1333.976038338658], (0.1, 3.9555555555555557): [-884.5521235521236, -1031.6653225806451, -1220.4976958525347, -1337.2541806020067, -1025.1607963246554], (0.1, 4.477777777777778): [-1102.5298013245033, -1075.1268533772652, -993.5818181818182, -1176.0202429149797, -737.974358974359], (0.1, 5.0): [-1527.9367088607594, -842.488612836439, -946.8333333333334, -931.3280757097792, -831.2682539682539]}

# %% [markdown]
# ### Compute Averages
#
# Average throughput is the number of finalized transactions divided by the duration of the experiment.
#
# Average main chain latency is the time for a transaction to be added to the global blocktree - the timestamp the transaction was generated.
#
# Average pool block latency is the time for a transaction to be added to a pool block AND referenced by a tree block.
#
# Average finalization latency is the time for a transaction to be k blocks deep - to be added to the global blocktree.

# %%
def compute_avg_std_dev(d):
    avgs = {}
    std_devs = {}
    print(d)
    for rate in d:
        avgs[rate] = sum(d[rate])/len(d[rate])
        std_devs[rate] = np.std(d[rate])
        
    return avgs, std_devs

avg_throughputs, throughput_sd = compute_avg_std_dev(throughputs)
avg_uniq_throughputs, uniq_throughput_sd = compute_avg_std_dev(unique_throughputs)
avg_pool_block_arr_lat , pool_block_arr_sd = compute_avg_std_dev(pool_block_arrival_latencies)
avg_pool_block_ref_lat, pool_block_ref_sd = compute_avg_std_dev(pool_block_ref_latencies)
avg_mca_lat, mca_lat_sd  = compute_avg_std_dev(main_chain_arrival_latencies)
avg_fin_lat, fin_lat_sd  = compute_avg_std_dev(finalization_latencies)
avg_emp, emp_sd = compute_avg_std_dev(emptiness)
# Out:
# {(0.1, 0.3): [67.715, 63.52166666666667, 60.96666666666667, 64.69666666666667, 60.67666666666667], (0.1, 0.8222222222222222): [54.16166666666667, 52.16833333333334, 53.641666666666666, 54.858333333333334, 57.596666666666664], (0.1, 1.3444444444444446): [49.84, 54.05833333333333, 56.04333333333334, 60.861666666666665, 52.141666666666666], (0.1, 1.866666666666667): [40.89833333333333, 48.55166666666667, 54.37, 56.526666666666664, 49.04666666666667], (0.1, 2.388888888888889): [47.946666666666665, 46.38333333333333, 48.321666666666665, 55.125, 43.721666666666664], (0.1, 2.911111111111111): [42.765, 37.03333333333333, 54.983333333333334, 51.25833333333333, 43.48833333333334], (0.1, 3.4333333333333336): [39.30833333333333, 44.22666666666667, 50.748333333333335, 41.00666666666667, 53.24666666666667], (0.1, 3.9555555555555557): [38.68833333333333, 33.406666666666666, 52.25833333333333, 37.843333333333334, 39.69166666666667], (0.1, 4.477777777777778): [38.61, 35.781666666666666, 59.25666666666667, 21.345, 46.205], (0.1, 5.0): [19.72833333333333, 45.218333333333334, 36.833333333333336, 28.301666666666666, 45.44]}
# {(0.1, 0.3): [18.045, 18.39666666666667, 18.645, 19.208333333333332, 19.198333333333334], (0.1, 0.8222222222222222): [10.118333333333334, 9.928333333333333, 12.13, 10.068333333333333, 10.026666666666667], (0.1, 1.3444444444444446): [11.01, 9.783333333333333, 9.088333333333333, 7.225, 7.593333333333334], (0.1, 1.866666666666667): [6.7316666666666665, 6.965, 6.968333333333334, 6.243333333333333, 8.165], (0.1, 2.388888888888889): [6.4783333333333335, 6.9383333333333335, 5.871666666666667, 8.11, 6.58], (0.1, 2.911111111111111): [6.398333333333333, 6.581666666666667, 5.93, 4.758333333333334, 6.42], (0.1, 3.4333333333333336): [4.89, 4.42, 4.373333333333333, 3.9116666666666666, 5.06], (0.1, 3.9555555555555557): [4.706666666666667, 5.613333333333333, 4.18, 5.368333333333333, 5.145], (0.1, 4.477777777777778): [3.9916666666666667, 4.001666666666667, 3.4183333333333334, 3.6216666666666666, 3.285], (0.1, 5.0): [4.1466666666666665, 3.7733333333333334, 5.883333333333334, 4.948333333333333, 3.966666666666667]}
# {(0.1, 0.3): [422.2872514946153, 421.34357364603125, 397.6600240587891, 367.11370411058954, 391.7086042265639], (0.1, 0.8222222222222222): [247.99956861476102, 228.51753175055265, 208.23332281986606, 224.37163963283405, 213.5257069726107], (0.1, 1.3444444444444446): [134.1399292407048, 137.8532243660617, 145.29459002188884, 176.4854411295612, 147.76428073543275], (0.1, 1.866666666666667): [123.17119854005712, 116.1854832258646, 134.12895667605648, 102.63945325466729, 112.00491413268298], (0.1, 2.388888888888889): [87.24566684353324, 89.4972553032986, 101.37524237271211, 93.96768229332606, 88.65803239096581], (0.1, 2.911111111111111): [81.44477756013092, 83.32139310696908, 67.21280039448996, 87.52241766625022, 79.84221750028912], (0.1, 3.4333333333333336): [83.03932003821753, 61.05872361990775, 80.15965710692178, 96.21535505299191, 78.77920537970805], (0.1, 3.9555555555555557): [71.68854678274423, 59.2373857508904, 65.6935470917367, 54.06737281303187, 50.006912419781024], (0.1, 4.477777777777778): [76.26833573157599, 57.85283654633201, 74.13636637507787, 65.5416695283717, 69.71610656534948], (0.1, 5.0): [52.997357705226065, 56.50262289756535, 55.39253308295434, 50.54865301652074, 69.99465349563859]}
# {(0.1, 0.3): [8.45327777994252, 8.282652739350125, 7.823349835719727, 7.2869694184756355, 7.2454430873217515], (0.1, 0.8222222222222222): [7.911252431258511, 9.337061034378475, 6.170303041450118, 10.192655256222722, 9.603333935504953], (0.1, 1.3444444444444446): [7.370688189685184, 8.178711915051709, 9.334844000544418, 9.503604761734465, 11.476148186916475], (0.1, 1.866666666666667): [3.341113218937008, 5.960290474624409, 10.005003068830847, 11.874806617780889, 9.431383309220061], (0.1, 2.388888888888889): [8.831669358432874, 6.67299471110893, 11.421245360572966, 11.74207588142177, 19.608943172222965], (0.1, 2.911111111111111): [13.176776311690737, 7.397258781349635, 13.992771623632791, 2.5613892036476544, 6.602528383951047], (0.1, 3.4333333333333336): [6.47659587299396, 13.435838323561926, 13.057300988984645, 10.632722132629993, 11.718314586161009], (0.1, 3.9555555555555557): [7.968529560468304, 14.802968722952121, 7.644372564921025, 6.7990511572786545, 13.13728707316362], (0.1, 4.477777777777778): [12.488176547891898, 17.496949861998594, 15.472047020580824, 6.916108335643269, 19.975098436249638], (0.1, 5.0): [8.548581470915165, 13.228970729247981, 5.790729356903623, 6.197105533686459, 11.678101196052484]}
# {(0.1, 0.3): [9.757315934003747, 8.066560607099579, 8.756598438034993, 7.625432966417224, 8.917218518676046], (0.1, 0.8222222222222222): [7.08054316513556, 9.014126965061257, 4.297995179912096, 9.787727146094628, 8.55963498755671], (0.1, 1.3444444444444446): [6.455307718533878, 6.347092929282611, 8.101067231762546, 7.324969472916603, 10.113473697879598], (0.1, 1.866666666666667): [2.1021879714972163, 4.997456342661084, 7.041188565269241, 5.225173816150206, 8.234530699378446], (0.1, 2.388888888888889): [7.0521414778036124, 3.7267838285492387, 7.285084533795381, 9.828594604475683, 8.623478741665885], (0.1, 2.911111111111111): [8.395588699592345, 7.148328294664633, 11.511319169278169, 0.05419293557058525, 0.8933597210324922], (0.1, 3.4333333333333336): [2.1464070849196974, 9.387953134223315, 7.549960800267771, -1.9612416970568625, 6.023500573794064], (0.1, 3.9555555555555557): [5.691714878227302, 2.0327243681527944, 4.851208407677463, 4.509229026362884, 2.2924149943291328], (0.1, 4.477777777777778): [2.179970338785805, 4.703923670496927, 12.812396573849242, 0.11509920348434818, 13.169767657860776], (0.1, 5.0): [3.845786769472618, 6.212369553133225, 2.8643666278436157, 4.148013443861553, 3.266234593787015]}
# {(0.1, 0.3): [22.944397465037135, 23.65024163595842, 23.73552009487866, 23.487210397612483, 22.81233211443678], (0.1, 0.8222222222222222): [13.244089121317407, 13.172170666414711, 12.446988695262847, 11.929629728108772, 12.195900441284257], (0.1, 1.3444444444444446): [7.964844394368605, 8.224372222411068, 6.731023738431287, 8.334592336968216, 11.421859693054008], (0.1, 1.866666666666667): [10.400794887689475, 8.207987780424133, 5.837221327627939, 7.165437426501934, 7.005405851381213], (0.1, 2.388888888888889): [5.5832683712045394, 6.577716072742226, 7.808588114859585, 4.226241657531864, 5.911473824815438], (0.1, 2.911111111111111): [4.0816721075265034, 8.153436713023048, 4.2631968398736415, 5.3618193471928555, 5.445619919026354], (0.1, 3.4333333333333336): [11.689336530743228, 7.209205533390121, 5.271809818271432, 7.517259810680867, 6.381029680738744], (0.1, 3.9555555555555557): [3.3428196044818126, 5.43707400078342, 3.354103534078854, 4.9935488577871805, 7.187909103178953], (0.1, 4.477777777777778): [5.298566369594682, 4.332051063654062, 2.0128441255898517, 4.978926564510737, 6.5551252660340475], (0.1, 5.0): [5.676652510555093, 5.383919163099735, 2.7994964841729857, 4.329288056479688, 7.471924120868809]}
# {(0.1, 0.3): [-1574.3715670436188, -1600.9620437956205, -1705.9054263565893, -1459.5197740112994, -1651.0], (0.1, 0.8222222222222222): [-1541.5391156462586, -1384.0536912751677, -1567.1042830540036, -1429.1589285714285, -1384.6954887218046], (0.1, 1.3444444444444446): [-1325.8173515981734, -1279.9543378995434, -1188.9679358717435, -1382.5521885521885, -1238.0947368421052], (0.1, 1.866666666666667): [-1530.9655172413793, -1192.2080536912752, -1169.6374622356495, -1289.3148148148148, -1406.3976744186045], (0.1, 2.388888888888889): [-1533.6030042918455, -1195.2485768500949, -1253.9036777583187, -955.1065989847716, -1218.5168738898756], (0.1, 2.911111111111111): [-1321.6036217303822, -1268.4864864864865, -1045.6566371681415, -1186.5933852140079, -1216.7393526405451], (0.1, 3.4333333333333336): [-1542.0868486352358, -770.0558659217877, -1092.2429718875503, -924.6964047936085, -1333.976038338658], (0.1, 3.9555555555555557): [-884.5521235521236, -1031.6653225806451, -1220.4976958525347, -1337.2541806020067, -1025.1607963246554], (0.1, 4.477777777777778): [-1102.5298013245033, -1075.1268533772652, -993.5818181818182, -1176.0202429149797, -737.974358974359], (0.1, 5.0): [-1527.9367088607594, -842.488612836439, -946.8333333333334, -931.3280757097792, -831.2682539682539]}

# %% [markdown]
# ### Extract Finalization Depth and Delta for Blocks

# %%
import csv
if os.path.isfile('../logs/stats.csv'):
    with open('../logs/stats.csv', newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        for row in reader:
            if row[0]=='Finalization depth':
                k = int(row[1])
            elif row[0]=='Average network latency for blocks (sec)':
                delta = float(row[1])

# %% [markdown]
# ### Plotting the results

# %%
import matplotlib.pylab as plt

def plot_results(title, xlabel, ylabel, x, y, std_dev):
    y_arr = np.array(list(y.values()))
    sd = np.array(list(std_dev.values()))
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.grid(True)
    
    plt.plot(x, y_arr, label='observed rate')
    plt.errorbar(x, y_arr, sd, capsize=5, linestyle='None', marker='*')
    plt.show()
    
x = np.array([key[1] for key in avg_throughputs.keys()])
plot_results(
f'Transaction Throughput vs. Pool Block Proposal Rate (k={k}, delta={delta})',
'Pool Block Proposal Rate (blocks/sec)',
'Throughput (txs/sec)',
x,
avg_throughputs,
throughput_sd,
)

# %%
plot_results(
f'Unique Transaction Throughput vs. Pool Block Proposal Rate (k={k}, delta={delta})',
'Pool Block Proposal Rate (blocks/sec)',
'Unique Throughput (txs/sec)',
x,
avg_uniq_throughputs,
uniq_throughput_sd,
)

# %%
plot_results(
f'Pool Block Arrival Latency vs. Pool Block Proposal Rate (k={k}, delta={delta})',
'Pool Block Proposal Rate (blocks/sec)',
'Pool Block Arrival Latency (sec)',
x,
avg_pool_block_arr_lat,
pool_block_arr_sd,
)

# %%
plot_results(
f'Pool Block Reference Latency vs. Pool Block Proposal Rate (k={k}, delta={delta})',
'Pool Block Proposal Rate (blocks/sec)',
'Pool Block Reference Latency (sec)',
x,
avg_pool_block_ref_lat,
pool_block_ref_sd,
)

# %%
plot_results(
f'Main Chain Arrival Latency vs. Pool Block Proposal Rate (k={k}, delta={delta})',
'Pool Block Proposal Rate (blocks/sec)',
'Main Chain Arrival Latency (sec)',
x,
avg_mca_lat,
mca_lat_sd,
)

# %%
plot_results(
f'Finalization Latency vs. Pool Block Proposal Rate (k={k}, delta={delta})',
'Pool Block Proposal Rate (blocks/sec)',
'Finalization Latency (sec)',
x,
avg_fin_lat,
fin_lat_sd,
)

# %%
plot_results(
f'Emptiness vs. Pool Block Proposal Rate (k={k}, delta={delta})',
'Pool Block Proposal Rate (blocks/sec)',
'Emptiness (txs)',
x,
avg_emp,
emp_sd,
)

# %% [markdown]
# ### Results
#
# We can look through the logs of the blocks to understand the process a block undergoes:

# %%
with open('../logs/blocks.csv') as f:
    for line in f.readlines()[:10]:
        print(line)
# Out:
# id,parent id,proposal timestamp,pool block timestamp,finalization timestamp,depth,finalized,emptiness,transactions
#
# Genesis,None,0,None,4.864402726772497,0,True,0,
#
# a6a19,Genesis,7.04396448390596,None,16.025248905452376,1,True,57,091966a4c2;6188bc41bb;e6a72a0e8c;321b9271c6;135395264d;1411ba3d72;c2c8f9de34;e67bbaeacd;d9ebd25cc4;d5cc8abae2;bd9046846f;de74b000d9;f84ae26dca;eb8dd7af97;eac6fd778a;8ecb7da5c7;cd4d820e54;9bcd36fe0b;7f5b80a950;3ff90380b1;d9d046fd8d;7d5649f433;5ebb70dcd1;272a85333f;687acad9c0;1bcdc3a8a7;4314914e91;fa03ef8bf6;d8bc9cba8c;217f773430;880d5b7e89;5d31a917cc;b4a3c5ff25;7b39de43c3;893da1c478;07b0bab5b7;3a2cf19771;2ab35f4aa8;0eebb2e3e9;aafec6a21d;7f65b2db50;782d72fae8;df1a2c3f83;3d5c322b81;5d4aaa5972;fa4ace0f19;bcc38e3970;49a9e24bdc;2a1a8baaea;3fe650f38a;8c4a2e484c
#
# c74f0,None,0.5092646192007728,,16.025248905452376,NA,True,50,
#
# fb718,None,0.727668110380381,,16.025248905452376,NA,True,50,
#
# f121a,None,3.731938499954605,,16.025248905452376,NA,True,74,091966a4c2;6188bc41bb;e6a72a0e8c;321b9271c6;135395264d;1411ba3d72;c2c8f9de34;e67bbaeacd;d9ebd25cc4;d5cc8abae2;bd9046846f;de74b000d9;f84ae26dca;eb8dd7af97;eac6fd778a;8ecb7da5c7;cd4d820e54;9bcd36fe0b;7f5b80a950;3ff90380b1;d9d046fd8d;7d5649f433;5ebb70dcd1;272a85333f
#
# 6cb3b,None,1.5196405294622022,,16.025248905452376,NA,True,0,
#
# 37652,None,1.638501884209702,,16.025248905452376,NA,True,0,
#
# 32e67,None,4.864402726772497,,16.025248905452376,NA,True,0,1e6a29641a;9f1f95b6d9;4a656ec89f;d16bbe4714
#
# c6717,None,5.608926106566511,,16.025248905452376,NA,True,70,091966a4c2;6188bc41bb;e6a72a0e8c;321b9271c6;135395264d;1411ba3d72;c2c8f9de34;e67bbaeacd;d9ebd25cc4;d5cc8abae2;bd9046846f;de74b000d9;f84ae26dca;eb8dd7af97;eac6fd778a;8ecb7da5c7;cd4d820e54;9bcd36fe0b;7f5b80a950;3ff90380b1;d9d046fd8d;7d5649f433;5ebb70dcd1;272a85333f;687acad9c0;1bcdc3a8a7;4314914e91;fa03ef8bf6;d8bc9cba8c;217f773430;880d5b7e89;5d31a917cc;b4a3c5ff25;7b39de43c3;893da1c478;07b0bab5b7;3a2cf19771;2ab35f4aa8;0eebb2e3e9;aafec6a21d;7f65b2db50;782d72fae8;df1a2c3f83;3d5c322b81;5d4aaa5972;fa4ace0f19;bcc38e3970;49a9e24bdc;2a1a8baaea;3fe650f38a;8c4a2e484c

# %% [markdown]
# Additionally, we can visualize the results to see the global blocktree. In the following image, blue nodes indicate tree blocks on the main chain and yellow blocks indicate tree blocks
# off the main chain (i.e. 'orphan blocks').
# ![title](../logs/blocktree.png)

# %% [markdown]
# We can look through the logs to understand the process a transaction undergoes. A transaction can
#
# 1) Be a pool or a tree transaction
# 2) Be on the main chain or not on the main chain
# 3) Be finalized or not finalized
#
# Hence, we will analyze each of the following cases:
# 1) A pool transaction on the main chain that is finalized
# 2) A pool transaction not on the main chain
# 3) A tree transaction on the main chain that is finalized
# 4) A tree transaction on the main chain that is not finalized
# 5) A tree transaction not on the main chain

# %%
import csv

finalized_main_chain_pool_tx = None
not_on_main_chain_pool_tx = None
finalized_main_chain_tree_tx = None
unfinalized_main_chain_tree_tx = None
not_on_main_chain_tree_tx = None

with open('../logs/transactions.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    row_count = 0
    for row in reader:
        if row['finalization timestamps']!='None'and row['main chain arrival timestamp']!='None' and row['pool block reference timestamp']!='None' and finalized_main_chain_pool_tx==None:
            finalized_main_chain_pool_tx = row
        elif row['main chain arrival timestamp']=='None' and row['pool block reference timestamp']!='None' and not_on_main_chain_pool_tx==None:
            not_on_main_chain_pool_tx = row
        elif row['finalization timestamps']!='None' and row['main chain arrival timestamp']!='None' and row['pool block reference timestamp']=='None' and finalized_main_chain_tree_tx==None:
            finalized_main_chain_tree_tx = row
        elif row['finalization timestamps']=='None' and row['main chain arrival timestamp']!='None' and row['pool block reference timestamp']=='None' and unfinalized_main_chain_tree_tx==None:
            unfinalized_main_chain_tree_tx = row
        elif row['main chain arrival timestamp']=='None' and row['pool block reference timestamp']=='None' and not_on_main_chain_tree_tx==None: 
            not_on_main_chain_tree_tx = row
        if row_count<10:
            print(row)
        row_count+=1
# Out:
# OrderedDict([('id', 'cc574fdfc2'), ('source node', '4'), ('generated timestamp', '0.82419973016835'), ('pool block arrival timestamp', '69.2572135003517'), ('pool block reference timestamp', '82.4787081763563'), ('main chain arrival timestamp', '79.45259692036491'), ('finalization timestamps', '14.330283729231041;18.00184892900625;18.769225351456047;21.491137286794903;24.282240557631923;17.45451592960101;21.47036142481904;19.127864991784516;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;72.58804955596815;71.4843264898458;87.16863978981196;87.16863978981196')])
# OrderedDict([('id', '90fb81c2de'), ('source node', '3'), ('generated timestamp', '0.12676335925356189'), ('pool block arrival timestamp', '69.2572135003517'), ('pool block reference timestamp', '82.4787081763563'), ('main chain arrival timestamp', '79.45259692036491'), ('finalization timestamps', '14.330283729231041;18.00184892900625;18.769225351456047;21.491137286794903;24.282240557631923;17.45451592960101;21.47036142481904;19.127864991784516;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;72.58804955596815;71.4843264898458;87.16863978981196;87.16863978981196')])
# OrderedDict([('id', '1e6a29641a'), ('source node', '5'), ('generated timestamp', '0.14728215186873964'), ('pool block arrival timestamp', '15.02875114618866'), ('pool block reference timestamp', '36.145180440336745'), ('main chain arrival timestamp', '36.145180440336745'), ('finalization timestamps', '14.23148537656961;16.025248905452376;14.330283729231041;18.00184892900625;18.769225351456047;21.491137286794903;24.282240557631923;17.45451592960101;21.47036142481904;19.127864991784516;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261')])
# OrderedDict([('id', '6f27f9d75e'), ('source node', '1'), ('generated timestamp', '1.6987440226734887'), ('pool block arrival timestamp', '69.2572135003517'), ('pool block reference timestamp', '82.4787081763563'), ('main chain arrival timestamp', '79.45259692036491'), ('finalization timestamps', '18.00184892900625;18.769225351456047;21.47036142481904;19.127864991784516;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;72.58804955596815;71.4843264898458;87.16863978981196;87.16863978981196')])
# OrderedDict([('id', '091966a4c2'), ('source node', '0'), ('generated timestamp', '0.9273919231456842'), ('pool block arrival timestamp', '15.02875114618866'), ('pool block reference timestamp', '36.145180440336745'), ('main chain arrival timestamp', '36.145180440336745'), ('finalization timestamps', '13.255501624043548;13.88102799797141;16.025248905452376;16.025248905452376;16.025248905452376;18.00184892900625;18.769225351456047;21.47036142481904;19.127864991784516;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261')])
# OrderedDict([('id', '54a91af022'), ('source node', '9'), ('generated timestamp', '2.208202839889797'), ('pool block arrival timestamp', '44.4507586090698'), ('pool block reference timestamp', '55.99037784319925'), ('main chain arrival timestamp', '51.8722835839404'), ('finalization timestamps', '18.769225351456047;21.47036142481904;37.21277352935261;37.21277352935261;41.1813262267238;50.7997237272406;60.61516939382854;60.61516939382854')])
# OrderedDict([('id', 'd7891b125e'), ('source node', '3'), ('generated timestamp', '1.682002127456645'), ('pool block arrival timestamp', '69.2572135003517'), ('pool block reference timestamp', '82.4787081763563'), ('main chain arrival timestamp', '79.45259692036491'), ('finalization timestamps', '18.769225351456047;21.491137286794903;17.45451592960101;21.47036142481904;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;72.58804955596815;71.4843264898458;87.16863978981196;87.16863978981196')])
# OrderedDict([('id', 'eddc50dedb'), ('source node', '7'), ('generated timestamp', '1.1088015491525898'), ('pool block arrival timestamp', '69.2572135003517'), ('pool block reference timestamp', '82.4787081763563'), ('main chain arrival timestamp', '79.45259692036491'), ('finalization timestamps', '18.769225351456047;21.47036142481904;37.21277352935261;37.21277352935261;72.58804955596815;71.4843264898458;87.16863978981196;87.16863978981196')])
# OrderedDict([('id', '7b1264e782'), ('source node', '4'), ('generated timestamp', '0.5073184260103504'), ('pool block arrival timestamp', '69.2572135003517'), ('pool block reference timestamp', '82.4787081763563'), ('main chain arrival timestamp', '79.45259692036491'), ('finalization timestamps', '14.330283729231041;18.769225351456047;24.282240557631923;21.47036142481904;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;72.58804955596815;71.4843264898458;87.16863978981196;87.16863978981196')])
# OrderedDict([('id', '14e901bef1'), ('source node', '1'), ('generated timestamp', '2.3266852230293633'), ('pool block arrival timestamp', '45.567839456754875'), ('pool block reference timestamp', '55.99037784319925'), ('main chain arrival timestamp', '51.8722835839404'), ('finalization timestamps', '18.00184892900625;28.635002023727857;27.65260417298941;37.21277352935261;37.21277352935261;37.21277352935261;38.004343266175944;39.33592302327134;42.72504620032788;49.21204723981467;56.9196153955881;60.61516939382854;60.61516939382854;60.61516939382854;60.61516939382854;60.61516939382854')])

# %%
print(f'Finalized Pool Transaction:\n{finalized_main_chain_pool_tx}')
print(f'Pool Transaction Not on Main Chain:\n{not_on_main_chain_pool_tx}')
print(f'Finalized Tree Transaction:\n{finalized_main_chain_tree_tx}')
print(f'Unfinalized Tree Transaction:\n{unfinalized_main_chain_tree_tx}')
print(f'Tree Transaction Not on Main Chain:\n{not_on_main_chain_tree_tx}')
# Out:
# Finalized Pool Transaction:
# OrderedDict([('id', 'cc574fdfc2'), ('source node', '4'), ('generated timestamp', '0.82419973016835'), ('pool block arrival timestamp', '69.2572135003517'), ('pool block reference timestamp', '82.4787081763563'), ('main chain arrival timestamp', '79.45259692036491'), ('finalization timestamps', '14.330283729231041;18.00184892900625;18.769225351456047;21.491137286794903;24.282240557631923;17.45451592960101;21.47036142481904;19.127864991784516;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;37.21277352935261;72.58804955596815;71.4843264898458;87.16863978981196;87.16863978981196')])
# Pool Transaction Not on Main Chain:
# OrderedDict([('id', '890699bf5a'), ('source node', '6'), ('generated timestamp', '11.552582426339631'), ('pool block arrival timestamp', '99.63337782084326'), ('pool block reference timestamp', '134.36411832978445'), ('main chain arrival timestamp', 'None'), ('finalization timestamps', 'None')])
# Finalized Tree Transaction:
# OrderedDict([('id', 'd8ad4feb76'), ('source node', '3'), ('generated timestamp', '7.702699742221067'), ('pool block arrival timestamp', 'None'), ('pool block reference timestamp', 'None'), ('main chain arrival timestamp', '85.48947874742346'), ('finalization timestamps', '91.59698234784679')])
# Unfinalized Tree Transaction:
# None
# Tree Transaction Not on Main Chain:
# OrderedDict([('id', '792247cf40'), ('source node', '9'), ('generated timestamp', '9.113069583290471'), ('pool block arrival timestamp', '84.12784659758915'), ('pool block reference timestamp', 'None'), ('main chain arrival timestamp', 'None'), ('finalization timestamps', 'None')])

# %% [markdown]
# Let's consider the first case of the finalized pool transaction. If we look into `blocks.csv`,
# we should be able to see that the transaction's main chain arrival timestamp and pool block timestamp
# should be equivalent to a tree block's proposal time. Additionally, the finalization time should be
# the tree block's finalization time.

# %%
with open('../logs/blocks.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    if finalized_main_chain_pool_tx!=None:
        for row in reader:
            if finalized_main_chain_pool_tx['id'] in row['transactions']:
                print(row)
                break
# Out:
# OrderedDict([('id', '974e1'), ('parent id', 'None'), ('proposal timestamp', '6.062715161905759'), ('pool block timestamp', ''), ('finalization timestamp', 'None'), ('depth', 'NA'), ('finalized', 'False'), ('emptiness', '0'), ('transactions', 'cc574fdfc2;7b1264e782')])

# %% [markdown]
# Now let's consider the second case of the pool transaction not on the main chain.
# We should see that it belongs to a block that is not finalized and not on the main chain, indicated
# by the fact the block's finalization timestamp and main chain arrival timestamp will both be `'None'`. However, the pool block timestamp should be equal to the block's proposal timestamp.

# %%
with open('../logs/blocks.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    if not_on_main_chain_pool_tx!=None:
        for row in reader:
            if not_on_main_chain_pool_tx['id'] in row['transactions']:
                print(row)
                break
# Out:
# OrderedDict([('id', 'edf31'), ('parent id', 'None'), ('proposal timestamp', '102.54628165904302'), ('pool block timestamp', ''), ('finalization timestamp', 'None'), ('depth', 'NA'), ('finalized', 'False'), ('emptiness', '0'), ('transactions', '890699bf5a;94443e9541;13c3f528e2;4ad07599ac;1eb6f5d000;2d0e119eaf;3806ff52c6;6dec0fa5d1;e870afbced;a7a79daee6;4cefc39495;c92b8b5080;265a22273c;47fcc8581e;5769bf11ac;2b6915529c;9f7b8f5d2b;825fac2ff0;dcf2dd8af7;98533524fb;1279483861;e73c0ed4ba;4d6199a77d;ac4c7e9970;7b698e04f9;a7a80a24c7;840ba26a59;68f27d9a7a;55b4c1d57f;b605446677;c39348e8f3;586b4ef1f0;567395626c;4d9235af6e;2e8606e891;8e63aea930;33272b3ead;745d0dc3d3;dc03699051;16be51d640;3489f83a6d;a28a00c54e;8917bc184b;8cc32901f3;79f260f332;8f54e12554;64d46e6a5b;79af361996;0ed70aa890;1732d37269;9dbdfd96ed')])

# %% [markdown]
# The third case is the tree finalized tree transaction on the main chain. We should see that it
# belongs to a block with equal finalization and main chain arrival timestamps, but a pool block timestamp equal to `'None'`.

# %%
with open('../logs/blocks.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    if finalized_main_chain_tree_tx!=None:
        for row in reader:
            if finalized_main_chain_tree_tx['id'] in row['transactions']:
                print(row)
                break
# Out:
# OrderedDict([('id', '3dff8'), ('parent id', 'ede40'), ('proposal timestamp', '85.48947874742346'), ('pool block timestamp', 'None'), ('finalization timestamp', '91.59698234784679'), ('depth', '5'), ('finalized', 'True'), ('emptiness', '-13676'), ('transactions', 'd8ad4feb76;09edae239e;00bfd41eee;f8c38d6537;06c629be35;29b8537c77;c7b444bdf1;82f8762f3f;5012022665;8240a7aafd;c2d96a8ab5;fd16d2aceb;9461de2815;fc6d0e5a29;bb5cb122ec;62d325c0ac;4d87c30192;07349bb12c;163d678032;3483cec840;c70ce25dbf;0cac176050;475c7a6665;0014612523;66661a7252;5b6df61dd4;7b39cb5421;c4ff8dbc57;16859da3fc;5a0bc86036;613ae03b68;902223f7fe;b2340fb19e;d9c944eaf6;4ba3b7bf39;41e49457da;af659c2f03;ffcba17176;15d6a6235f;c3871fe3de;03cfbd22e8;4f2c0fad48;6eecab1de8;583ce86b99;aab34078e0;ad7e53e0fc;8f2a782227;dc3568ab81;8b12c1a0f1;77fe50f72c;03a0168d3b')])

# %% [markdown]
# The fourth case is the unfinalized tree transaction on the main chain. We should see that it
# belongs to a block with equal main chain arrival timestamp, but pool block and finalization
# timestamps equal to `'None'`.

# %%
with open('../logs/blocks.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    if unfinalized_main_chain_tree_tx!=None:
        for row in reader:
            if unfinalized_main_chain_tree_tx['id'] in row['transactions']:
                print(row)
                break

# %% [markdown]
# The final case is the tree transaction not on the main chain. The block is not used for any statistics and is not logged.
