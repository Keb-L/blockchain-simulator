# %%
import pandas as pd
import numpy as np

blocks_df = pd.read_csv('../logs/blocks.csv')
transactions_df = pd.read_csv('../logs/transactions.csv')
# Out:
#           id Parent id  Proposal timestamp Finalization timestamp  Depth  \
# 0    Genesis      None            0.000000     13.089514838793558      0
# 1      d6160   Genesis           13.089515     22.541794180716764      1
# 2      41b44     d6160           22.541794      26.49851064813657      2
# 3      36f8e     41b44           26.498511     30.276422766900865      3
# 4      de010     41b44           27.599200                   None      3
# 5      10a42     36f8e           30.276423      57.23707814956196      4
# 6      c8439     10a42           57.237078      62.29531724948176      5
# 7      bc0f5     c8439           60.734284                   None      6
# 8      d7e01     c8439           62.295317      78.66574199305228      6
# 9      35421     d7e01           78.665742     118.85028001681839      7
# 10     cc21c     35421          118.850280     125.15539535126096      8
# 11     6bef2     cc21c          125.155395      134.8826033300254      9
# ...
